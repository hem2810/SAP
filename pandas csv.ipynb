# %%
import pandas as pd
df = pd.read_csv('parks.csv')
df
# Out:
#    Park Code                                       Park Name       State  \
# 0       ACAD                            Acadia National Park          ME
# 1       ARCH                            Arches National Park          UT
# 2       BADL                          Badlands National Park          SD
# 3       BIBE                          Big Bend National Park          TX
# 4       BISC                          Biscayne National Park          FL
# 5       BLCA      Black Canyon of the Gunnison National Park          CO
# 6       BRCA                      Bryce Canyon National Park          UT
# 7       CANY                       Canyonlands National Park          UT
# 8       CARE                      Capitol Reef National Park          UT
# 9       CAVE                  Carlsbad Caverns National Park          NM
# 10      CHIS                   Channel Islands National Park          CA
# 11      CONG                          Congaree National Park          SC
# ...

# %%
#Only give 3 rows
df[:3]
# Out:
#   Park Code               Park Name State   Acres  Latitude  Longitude
# 0      ACAD    Acadia National Park    ME   47390     44.35     -68.21
# 1      ARCH    Arches National Park    UT   76519     38.68    -109.57
# 2      BADL  Badlands National Park    SD  242756     43.75    -102.50

# %%
#only give between 15 to 21
df[15:21]
# Out:
#    Park Code                                       Park Name   State    Acres  \
# 15      DEVA                      Death Valley National Park  CA, NV  4740912
# 16      DRTO                      Dry Tortugas National Park      FL    64701
# 17      EVER                        Everglades National Park      FL  1508538
# 18      GAAR  Gates Of The Arctic National Park and Preserve      AK  7523898
# 19      GLAC                           Glacier National Park      MT  1013572
# 20      GLBA          Glacier Bay National Park and Preserve      AK  3224840
#
#     Latitude  Longitude
# 15     36.24    -116.82
# 16     24.63     -82.87
# 17     25.32     -80.93
# 18     67.78    -153.30
# 19     48.80    -114.00
# 20     58.50    -137.00

# %%
df[:5]
# Out:
#   Park Code               Park Name State   Acres  Latitude  Longitude
# 0      ACAD    Acadia National Park    ME   47390     44.35     -68.21
# 1      ARCH    Arches National Park    UT   76519     38.68    -109.57
# 2      BADL  Badlands National Park    SD  242756     43.75    -102.50
# 3      BIBE  Big Bend National Park    TX  801163     29.25    -103.25
# 4      BISC  Biscayne National Park    FL  172924     25.65     -80.08

# %%
#only last five rows
df.tail(5)
# Out:
#    Park Code                                       Park Name       State  \
# 51      WICA                         Wind Cave National Park          SD
# 52      WRST  Wrangell - St Elias National Park and Preserve          AK
# 53      YELL                       Yellowstone National Park  WY, MT, ID
# 54      YOSE                          Yosemite National Park          CA
# 55      ZION                              Zion National Park          UT
#
#       Acres  Latitude  Longitude
# 51    28295     43.57    -103.48
# 52  8323148     61.00    -142.00
# 53  2219791     44.60    -110.50
# 54   761266     37.83    -119.50
# 55   146598     37.30    -113.05

# %%
#only first five rows
df.head(5)
# Out:
#   Park Code               Park Name State   Acres  Latitude  Longitude
# 0      ACAD    Acadia National Park    ME   47390     44.35     -68.21
# 1      ARCH    Arches National Park    UT   76519     38.68    -109.57
# 2      BADL  Badlands National Park    SD  242756     43.75    -102.50
# 3      BIBE  Big Bend National Park    TX  801163     29.25    -103.25
# 4      BISC  Biscayne National Park    FL  172924     25.65     -80.08

# %%
df[50:52]['Park Name']
# Out:
# 50    Voyageurs National Park
# 51    Wind Cave National Park
# Name: Park Name, dtype: object

# %%
df[50:54]
# Out:
#    Park Code                                       Park Name       State  \
# 50      VOYA                         Voyageurs National Park          MN
# 51      WICA                         Wind Cave National Park          SD
# 52      WRST  Wrangell - St Elias National Park and Preserve          AK
# 53      YELL                       Yellowstone National Park  WY, MT, ID
#
#       Acres  Latitude  Longitude
# 50   218200     48.50     -92.88
# 51    28295     43.57    -103.48
# 52  8323148     61.00    -142.00
# 53  2219791     44.60    -110.50

# %%
df.iloc[50:54]
# Out:
#    Park Code                                       Park Name       State  \
# 50      VOYA                         Voyageurs National Park          MN
# 51      WICA                         Wind Cave National Park          SD
# 52      WRST  Wrangell - St Elias National Park and Preserve          AK
# 53      YELL                       Yellowstone National Park  WY, MT, ID
#
#       Acres  Latitude  Longitude
# 50   218200     48.50     -92.88
# 51    28295     43.57    -103.48
# 52  8323148     61.00    -142.00
# 53  2219791     44.60    -110.50

# %%
df['State']
# Out:
# 0             ME
# 1             UT
# 2             SD
# 3             TX
# 4             FL
# 5             CO
# 6             UT
# 7             UT
# 8             UT
# 9             NM
# 10            CA
# 11            SC
# 12            OR
# 13            OH
# 14            AK
# 15        CA, NV
# 16            FL
# 17            FL
# 18            AK
# 19            MT
# 20            AK
# 21            NV
# 22            AZ
# 23            CO
# 24        TN, NC
# 25            WY
# 26            TX
# 27            HI
# 28            HI
# 29            AR
# 30            MI
# 31            CA
# 32            AK
# 33            AK
# 34            AK
# 35            AK
# 36            CA
# 37            KY
# 38            CO
# 39            WA
# 40            WA
# 41            WA
# 42            AZ
# 43            CA
# 44            CA
# 45            CO
# 46            AZ
# 47            CA
# 48            VA
# 49            ND
# 50            MN
# 51            SD
# ...

# %%
df['State'].loc[15]
# Out:
# 'CA, NV'

# %%
df[15:21]['Acres'].mean()
# Out:
# 3012743.5

# %%
df[df['Park Code']=='ACAD']['Park Name']
# Out:
# 0    Acadia National Park
# Name: Park Name, dtype: object

# %%
df['Acres'].loc[(df['Park Code']=='GRSA') | (df['Park Name']=='BADL') | (df['Park Name']=='YELL')].sum()
# Out:
# 42984

# %%
df[df['Acres']<10000].count()
# Out:
# Park Code    1
# Park Name    1
# State        1
# Acres        1
# Latitude     1
# Longitude    1
# dtype: int64

# %%
len(df['Acres'][df['Acres']<10000])
# Out:
# 1

# %%
len(df['Longitude'][df['Longitude']<-90])
# Out:
# 46

# %%
x=df['Acres'][df['Park Name']=='Yellowstone National Park'].iloc[0]
x
# Out:
# 2219791

# %%
df[df['Acres']>x].sort_values(by='Acres')['Park Name'].values[0]
# Out:
# 'Lake Clark National Park and Preserve'

# %%
y=df['Acres'][df['State']!='AK'].max()

# %%
df['Park Name'] [df['Acres']==y]
# Out:
# 15    Death Valley National Park
# Name: Park Name, dtype: object

# %%
z=df['Park Name']
len(df[df['State'].str.contains(',')])
# Out:
# 3

# %%
df[df['State'].str.contains(',')].count()
# Out:
# Park Code    3
# Park Name    3
# State        3
# Acres        3
# Latitude     3
# Longitude    3
# dtype: int64
