# %% [markdown]
# ## Module 1 Assessment CU
#
# Hemkumari Patel-Sardar Patel College Of Engineering En.Roll-201240116004
# Time:60 Mintues Date:13/10/2022

# %% [markdown]
# #### Sectoin 3

# %%
# 1.

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6,7,8]
y = [2,3,1,3,1,4,2,3]
plt.plot(x,y)
plt.plot(y, marker = 'o')
plt.plot(y, color = 'b')
plt.show()

# %% [markdown]
# ##### Section 1

# %%
# 2.

# %%
def list_length(list):
    return len(list)
li=[2,1,5,6,4,8,9,5,9]
print("length",list_length(li))
# Out:
# length 9

# %%
# 5.

# %%
Fahrenheit = 54
Celsius = ((Fahrenheit-32)*5)/9
print("temperature in celsius is");
print(Celsius);
# Out:
# temperature in celsius is
# 12.222222222222221

# %% [markdown]
# #### Section 2

# %%
# 7

# %%
import numpy as np
arr = np.matrix('[64, 1; 12, 3]')
mean = arr.mean()
print(mean)
# Out:
# 20.0

# %%
# 1

# %%
import numpy as np
from numpy import matrix as mx

x=np.array([13,24])
y=np.array([34,46])

z=mx.dot(x,y)
print("sum of two matrix:",z)
# Out:
# sum of two matrix: 1546

# %% [markdown]
# #### Section 4

# %%
mkdir-create a directory
rmdir-remove directory
cd-enter in a directory
..cd-exit on a directory 
ls-list out all directory
