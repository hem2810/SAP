# %%
import numpy as np
c_data = np.loadtxt("cric.tsv.txt",skiprows=1)

# %%
c_data.shape
# Out:
# (15, 4)

# %%
Sachin = c_data[:,1]
Dravid = c_data[:,2]
India = c_data[:,3]

# %%
Sachin
Sachin.shape
# Out:
# (15,)

# %%
Sachin_x = c_data[1:6,1:3]
print(Sachin_x)
# Out:
# [[ 11.  62.]
#  [  8.  85.]
#  [ 71.  24.]
#  [104.  17.]
#  [ 18. 104.]]

# %% [markdown]
# # find the maximum score of Sachin,Dravid & Team India

# %%
np.max(Sachin)
# Out:
# 147.0

# %%
np.max(Dravid)
# Out:
# 146.0

# %%
np.max(India)
# Out:
# 370.0

# %%
def stats(col):
    print('Mean',np.mean(col))
    print('Median',np.median(col))

# %%
stats(Sachin)
# Out:
# Mean 63.6
# Median 71.0

# %%
stats(Dravid)
# Out:
# Mean 71.06666666666666
# Median 74.0

# %%
stats(India)
# Out:
# Mean 281.26666666666665
# Median 288.0

# %%
np.count_nonzero(Sachin>99)
# Out:
# 4

# %%
np.count_nonzero(Dravid>99)
# Out:
# 3

# %%
Sachin_cumscores = np.cumsum(Sachin)
np.searchsorted(Sachin_cumscores,1000)
# Out:
# 15

# %%
Dravid_cumscores = np.cumsum(Dravid)
np.searchsorted(Dravid_cumscores,1000)
# Out:
# 14

# %%
import matplotlib.pyplot as plt
x = [1,2,3]
y = [3,4,5]
plt.plot(x,y)
plt.plot(y, marker = 'o')
plt.plot(y, color = 'b')
plt.show()

# %%
plt.plot(y, linestyle = 'dotted')

# %%
import matplotlib.pyplot as plt
x = np.array([1,2,3,4])
y = x*2
plt.plot(x,y)
x1 = [1,2,3,8]
y1 = [3,4,5,9]
plt.plot(x1,y1,'-')
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt  
# Compute the x and y coordinates for points on a sine curve 
x = np.arange(0, 3 * np.pi, 0.1) 
y = np.sin(x) 
plt.title("sine wave form") 
# Plot the points using matplotlib 
plt.plot(x, y) 
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt
x = np.arange(0, 3*np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)
plt.subplot(2,1,1)
plt.plot(x,y_sin)  
plt.title('sine')
plt.subplot(2,1,2)
plt.plot(x,y_cos)  
plt.title('cosine')
plt.show()

# %%
from matplotlib import pyplot as plt 
x = [5,8,10] 
y = [12,16,6]  

x2 = [6,9,11] 
y2 = [6,15,7] 
plt.bar(x, y, align = 'center') 
plt.bar(x2, y2, color = 'g', align = 'center') 
plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis')  

plt.show()

# %%
from matplotlib import pyplot as plt 
import numpy as np  
   
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a, bins = [0,20,40,60,80,100]) 
plt.title("histogram") 
plt.show()

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d4ac713e20>,
#   <matplotlib.patches.Wedge at 0x1d4aca09e80>,
#   <matplotlib.patches.Wedge at 0x1d4ac7286a0>],
#  [Text(0.8532824353172374, 0.6941967196545118, ''),
#   Text(-0.8532824028195425, 0.6941967595995449, ''),
#   Text(0.2238015617481669, -1.0769925073829816, '')])

# %%
plt.scatter(x,y)

# %%
from matplotlib import pyplot as plt 
import numpy as np 
cars = ['AUDI','BMW','FORD','TESLA','JAGUAR','MERCEDES']
data = [23,17,35,29,12,41]
fig = plt.figure(figsize=(10,7))
plt.pie(data,labels = cars)
plt.show()

# %%
plt.plot(x)
plt.legend(["green"])
plt.show()

# %%
from mpl_toolkits import mplot3d
from matplotlib import pyplot as plt 
import numpy as np 
fig = plt.figure()
ax = plt.axes(projection = '3d')
z=np.linspace(0,1,100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)
ax.plot3D(x,y,z,'green')
ax.set_title('3D line plot')
plt.show()
